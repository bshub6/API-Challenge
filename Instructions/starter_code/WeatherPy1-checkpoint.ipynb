# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import random
import csv as csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
city_file = "output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
counter = 0
randlat = []
randlngs = []
cities = []

# Create a set of random lat and lng combinations
while len(randlat)< 500:
    lats = np.random.uniform(low=-90, high=90)
    lngs = np.random.uniform(low=-180, high=180)
    randlat.append(lats)
    randlngs.append(lngs)            
    counter += 1
    
coord_df = pd.DataFrame({"lats":randlat, "lngs": randlngs})  
coord_df.head()
# Out:
#         lats        lngs
# 0  33.193233 -142.198819
# 1  38.322692  -95.748679
# 2  84.536185  141.010849
# 3  71.363364 -151.039864
# 4  -6.130544   28.059524

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
#print(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build query URL to begin call
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + api_key

#Set up list for responses
date = []
country = []
lat = []
lon = []
temp_max = []
humidity = []
cloud = []
wind = []
_cities = []
print("Beginning Data Retrieval")

for city in cities:
    url_city = url + "&q=" + str(city)
    #print(url_city)
    #convert to json  
    try:
        city_data = requests.get(url_city).json()
        country.append(city_data['sys']['country'])
        date.append(city_data['dt'])
        lat.append(city_data['coord']['lat'])
        lon.append(city_data['coord']['lon'])
        temp_max.append(city_data['main']['temp_max'])
        humidity.append(city_data['main']['humidity']) 
        cloud.append(city_data['clouds']['all'])
        wind.append(city_data['wind']['speed'])
        _cities.append(city)
        print(f"retreiving data | {city}")
    except:
        print("If city is not found, skipping")
print("Retrieval is complete!")
data_dict = {'city': _cities,
                  'country': country,
                  'latitude': lat,
                  'longitude': lon,
                  'max temp': temp_max,
                  'humidity': humidity,
                  'cloudiness': cloud,
                  'windspeed': wind} 
                                               
#print(data_dict)
df = pd.DataFrame.from_dict(data_dict)
df.head()
# Out:
# Beginning Data Retrieval
# retreiving data | port elizabeth
# retreiving data | saint george
# retreiving data | kotelnikovo
# retreiving data | busselton
# retreiving data | pochutla
# retreiving data | matara
# retreiving data | albany
# retreiving data | margate
# retreiving data | bulolo
# retreiving data | hilo
# retreiving data | antalaha
# retreiving data | balkanabat
# retreiving data | bluff
# retreiving data | rikitea
# If city is not found, skipping
# retreiving data | broken hill
# retreiving data | salekhard
# retreiving data | chernyshevskiy
# retreiving data | ushuaia
# retreiving data | taybad
# If city is not found, skipping
# retreiving data | new norfolk
# retreiving data | sao joao da barra
# retreiving data | mataura
# retreiving data | butaritari
# If city is not found, skipping
# retreiving data | hermanus
# retreiving data | quatre cocos
# retreiving data | arraial do cabo
# retreiving data | longyearbyen
# retreiving data | khor
# If city is not found, skipping
# retreiving data | avarua
# retreiving data | lavrentiya
# retreiving data | nikolskoye
# retreiving data | carnarvon
# retreiving data | saryg-sep
# retreiving data | severo-kurilsk
# retreiving data | barrow
# retreiving data | neuquen
# retreiving data | rio gallegos
# retreiving data | changtu
# retreiving data | qaanaaq
# retreiving data | lebrija
# retreiving data | bredasdorp
# retreiving data | moose factory
# If city is not found, skipping
# If city is not found, skipping
# retreiving data | kodiak
# retreiving data | cherskiy
# retreiving data | alofi
# retreiving data | faanui
# retreiving data | rio grande
# retreiving data | indramayu
# retreiving data | punta arenas
# retreiving data | kaitangata
# retreiving data | berlevag
# retreiving data | thompson
# retreiving data | ribeira grande
# If city is not found, skipping
# retreiving data | launceston
# retreiving data | mar del plata
# retreiving data | belmonte
# retreiving data | kieta
# retreiving data | kapaa
# retreiving data | atuona
# retreiving data | pangkalanbuun
# retreiving data | muroto
# retreiving data | katima mulilo
# If city is not found, skipping
# retreiving data | coihaique
# retreiving data | lebu
# retreiving data | jamestown
# retreiving data | eureka
# retreiving data | zeya
# retreiving data | filingue
# retreiving data | fare
# retreiving data | hithadhoo
# retreiving data | usak
# retreiving data | provideniya
# retreiving data | luderitz
# retreiving data | le port
# retreiving data | ponta do sol
# retreiving data | vardo
# retreiving data | rockland
# If city is not found, skipping
# If city is not found, skipping
# retreiving data | oistins
# retreiving data | dikson
# retreiving data | boa vista
# retreiving data | airai
# retreiving data | aitape
# retreiving data | batemans bay
# retreiving data | jonuta
# If city is not found, skipping
# retreiving data | saint-philippe
# If city is not found, skipping
# retreiving data | svetlaya
# retreiving data | gat
# If city is not found, skipping
# retreiving data | hudson bay
# retreiving data | malanje
# retreiving data | sampit
# retreiving data | cabo san lucas
# retreiving data | port arthur
# retreiving data | ilulissat
# retreiving data | leningradskiy
# retreiving data | iskateley
# retreiving data | kalabo
# If city is not found, skipping
# retreiving data | souillac
# retreiving data | jiuquan
# retreiving data | gela
# retreiving data | sorland
# If city is not found, skipping
# If city is not found, skipping
# retreiving data | salalah
# retreiving data | lazarev
# retreiving data | hobart
# retreiving data | bethel
# retreiving data | mogadishu
# retreiving data | buala
# retreiving data | tiksi
# retreiving data | jumla
# retreiving data | port alfred
# retreiving data | kaeo
# retreiving data | edd
# retreiving data | naron
# retreiving data | maniitsoq
# retreiving data | pingdingshan
# retreiving data | channel-port aux basques
# retreiving data | georgetown
# retreiving data | sobolevo
# retreiving data | vaini
# retreiving data | sibu
# retreiving data | jackson
# retreiving data | torbay
# retreiving data | walvis bay
# retreiving data | rabo de peixe
# retreiving data | seoul
# If city is not found, skipping
# retreiving data | gibara
# If city is not found, skipping
# retreiving data | hasaki
# retreiving data | hervey bay
# retreiving data | puerto ayora
# retreiving data | inverness
# retreiving data | upernavik
# retreiving data | port keats
# retreiving data | lyuban
# retreiving data | castro
# retreiving data | dekernes
# retreiving data | broome
# retreiving data | husavik
# retreiving data | la libertad
# retreiving data | igarka
# retreiving data | talnakh
# retreiving data | dagohoy
# retreiving data | namatanai
# retreiving data | commerce
# retreiving data | yerbogachen
# retreiving data | te anau
# retreiving data | thunder bay
# retreiving data | new milford
# retreiving data | geraldton
# retreiving data | high rock
# retreiving data | san rafael
# retreiving data | padang
# retreiving data | eden
# retreiving data | kahului
# If city is not found, skipping
# If city is not found, skipping
# retreiving data | beringovskiy
# If city is not found, skipping
# retreiving data | abaza
# retreiving data | diapaga
# retreiving data | lagoa
# retreiving data | altay
# retreiving data | ancud
# retreiving data | katsuura
# retreiving data | snasa
# retreiving data | tsiroanomandidy
# retreiving data | vershino-darasunskiy
# retreiving data | bushehr
# retreiving data | victor harbor
# retreiving data | dekar
# retreiving data | kourou
# retreiving data | harper
# retreiving data | barcelos
# retreiving data | ercis
# retreiving data | bilma
# retreiving data | port blair
# retreiving data | rudnogorsk
# retreiving data | constitucion
# If city is not found, skipping
# retreiving data | rosarito
# retreiving data | tuktoyaktuk
# retreiving data | saint-georges
# retreiving data | campbellton
# retreiving data | pisco
# retreiving data | chuy
# retreiving data | tamiahua
# retreiving data | saskylakh
# If city is not found, skipping
# retreiving data | mahebourg
# retreiving data | camocim
# retreiving data | ostrovnoy
# retreiving data | saldanha
# retreiving data | los llanos de aridane
# retreiving data | balabac
# retreiving data | tuatapere
# retreiving data | port hedland
# retreiving data | hit
# retreiving data | kijang
# retreiving data | lasa
# retreiving data | dudinka
# retreiving data | sinnamary
# retreiving data | doha
# retreiving data | bambous virieux
# retreiving data | totskoye
# retreiving data | codrington
# If city is not found, skipping
# retreiving data | antsohihy
# retreiving data | karoi
# If city is not found, skipping
# retreiving data | karratha
# retreiving data | kruisfontein
# retreiving data | shitanjing
# retreiving data | angoche
# retreiving data | sitka
# retreiving data | dauriya
# retreiving data | saint-pierre
# retreiving data | ekibastuz
# retreiving data | chokurdakh
# retreiving data | tierralta
# retreiving data | touros
# retreiving data | turukhansk
# retreiving data | tiznit
# retreiving data | iqaluit
# retreiving data | tavistock
# retreiving data | east london
# retreiving data | half moon bay
# retreiving data | byron bay
# retreiving data | juneau
# If city is not found, skipping
# If city is not found, skipping
# retreiving data | westport
# retreiving data | paraiso
# retreiving data | port augusta
# retreiving data | joshimath
# retreiving data | ahipara
# retreiving data | kavieng
# retreiving data | ouallam
# retreiving data | presidencia roque saenz pena
# retreiving data | pevek
# If city is not found, skipping
# retreiving data | qandala
# retreiving data | bud
# retreiving data | omboue
# retreiving data | policarpa
# retreiving data | ewa beach
# retreiving data | honiara
# retreiving data | deputatskiy
# If city is not found, skipping
# retreiving data | dingle
# retreiving data | bagli
# retreiving data | rincon
# retreiving data | fortuna
# retreiving data | jaunjelgava
# retreiving data | fairbanks
# retreiving data | labytnangi
# retreiving data | severnoye
# retreiving data | teahupoo
# retreiving data | sibolga
# If city is not found, skipping
# retreiving data | mnogovershinnyy
# retreiving data | chimore
# retreiving data | marsa matruh
# retreiving data | ayan
# If city is not found, skipping
# retreiving data | novyy urengoy
# retreiving data | san miguel
# retreiving data | waipawa
# retreiving data | vylok
# retreiving data | yar-sale
# retreiving data | miltenberg
# retreiving data | alyangula
# retreiving data | vostok
# retreiving data | karakol
# retreiving data | visnes
# retreiving data | bonavista
# If city is not found, skipping
# retreiving data | port lincoln
# retreiving data | banda aceh
# retreiving data | manzhouli
# retreiving data | lukovetskiy
# retreiving data | natal
# retreiving data | tekeli
# If city is not found, skipping
# retreiving data | kotido
# retreiving data | sri aman
# If city is not found, skipping
# retreiving data | vila franca do campo
# retreiving data | baruun-urt
# retreiving data | kindia
# retreiving data | raymond
# retreiving data | gizo
# retreiving data | atambua
# retreiving data | komsomolskiy
# retreiving data | araouane
# retreiving data | adrar
# retreiving data | dunedin
# retreiving data | cayenne
# retreiving data | cape town
# retreiving data | vestmannaeyjar
# retreiving data | kaseda
# retreiving data | granja
# retreiving data | klaksvik
# retreiving data | piranshahr
# retreiving data | moree
# retreiving data | kriel
# retreiving data | urusha
# retreiving data | mora
# retreiving data | albion
# retreiving data | clyde river
# retreiving data | khandyga
# retreiving data | charters towers
# retreiving data | esperance
# retreiving data | jiwani
# retreiving data | vitim
# retreiving data | north myrtle beach
# retreiving data | ambilobe
# retreiving data | okhotsk
# retreiving data | lensk
# retreiving data | grand gaube
# retreiving data | itaituba
# retreiving data | kavaratti
# retreiving data | faya
# If city is not found, skipping
# retreiving data | bojnurd
# If city is not found, skipping
# retreiving data | neyshabur
# retreiving data | klyuchi
# If city is not found, skipping
# retreiving data | sabha
# retreiving data | marsh harbour
# retreiving data | tecoanapa
# retreiving data | itoman
# retreiving data | mabaruma
# retreiving data | briancon
# retreiving data | jalu
# retreiving data | tottori
# retreiving data | sembakung
# retreiving data | nishihara
# retreiving data | nieuw amsterdam
# retreiving data | cidreira
# If city is not found, skipping
# retreiving data | coquimbo
# retreiving data | lermontovka
# retreiving data | iranshahr
# retreiving data | belyy yar
# retreiving data | bayan
# retreiving data | vanavara
# retreiving data | santa marta
# retreiving data | kanniyakumari
# retreiving data | zyryanka
# retreiving data | muzhi
# retreiving data | sturgeon falls
# retreiving data | mogwase
# retreiving data | tilichiki
# If city is not found, skipping
# retreiving data | victoria
# retreiving data | opuwo
# retreiving data | kudat
# retreiving data | tasiilaq
# retreiving data | akom
# If city is not found, skipping
# retreiving data | nanortalik
# retreiving data | corn island
# retreiving data | palora
# retreiving data | tabou
# retreiving data | kupang
# retreiving data | loharu
# retreiving data | biloela
# retreiving data | mahdalynivka
# retreiving data | hay river
# retreiving data | dragoman
# retreiving data | plettenberg bay
# retreiving data | hofn
# retreiving data | munirabad
# retreiving data | trinidad
# retreiving data | sann
# retreiving data | matane
# retreiving data | tulum
# retreiving data | middlebury
# If city is not found, skipping
# retreiving data | biak
# retreiving data | borogontsy
# retreiving data | san cristobal
# retreiving data | timberlake
# retreiving data | otane
# retreiving data | kawalu
# retreiving data | pozo colorado
# If city is not found, skipping
# retreiving data | matay
# If city is not found, skipping
# retreiving data | nyurba
# retreiving data | zhangye
# retreiving data | sao filipe
# If city is not found, skipping
# retreiving data | ravar
# retreiving data | batagay
# retreiving data | copiapo
# retreiving data | la palma
# retreiving data | matamoros
# retreiving data | plouzane
# retreiving data | lata
# retreiving data | anadyr
# retreiving data | quepos
# retreiving data | pombas
# retreiving data | nueva granada
# retreiving data | socorro
# retreiving data | mount pleasant
# If city is not found, skipping
# retreiving data | bairnsdale
# retreiving data | kimbe
# retreiving data | mizdah
# retreiving data | roebourne
# retreiving data | mekhe
# retreiving data | dauphin
# retreiving data | port hardy
# retreiving data | yellowknife
# retreiving data | san patricio
# retreiving data | lompoc
# retreiving data | rosita
# retreiving data | minas
# retreiving data | davila
# retreiving data | ippy
# retreiving data | isangel
# retreiving data | merauke
# retreiving data | broadstairs
# If city is not found, skipping
# retreiving data | san javier
# If city is not found, skipping
# retreiving data | irtyshskiy
# If city is not found, skipping
# retreiving data | copacabana
# retreiving data | khatanga
# retreiving data | bathsheba
# retreiving data | dongsheng
# retreiving data | chikmagalur
# retreiving data | shingu
# retreiving data | alugan
# retreiving data | tanhacu
# retreiving data | shimanovsk
# If city is not found, skipping
# retreiving data | ozernovskiy
# retreiving data | kangaatsiaq
# retreiving data | sisimiut
# retreiving data | batabano
# retreiving data | princeton
# retreiving data | yulara
# retreiving data | gornopravdinsk
# retreiving data | namibe
# If city is not found, skipping
# retreiving data | point pleasant
# retreiving data | khvorostyanka
# retreiving data | kargasok
# retreiving data | coahuayana
# retreiving data | lingao
# retreiving data | masallatah
# retreiving data | lazaro cardenas
# retreiving data | bereda
# If city is not found, skipping
# retreiving data | grindavik
# If city is not found, skipping
# retreiving data | srednekolymsk
# retreiving data | la ronge
# retreiving data | dymer
# retreiving data | pringsewu
# retreiving data | istria
# retreiving data | aykhal
# retreiving data | gravdal
# If city is not found, skipping
# retreiving data | taoudenni
# If city is not found, skipping
# If city is not found, skipping
# retreiving data | tari
# If city is not found, skipping
# retreiving data | kolondieba
# retreiving data | vila velha
# retreiving data | alice springs
# retreiving data | poum
# retreiving data | chenzhou
# retreiving data | sotouboua
# retreiving data | oga
# retreiving data | luganville
# If city is not found, skipping
# retreiving data | san carlos de bariloche
# retreiving data | guerrero negro
# retreiving data | bukama
# retreiving data | zhuanghe
# retreiving data | kaminokawa
# retreiving data | vaitape
# If city is not found, skipping
# retreiving data | phan thiet
# retreiving data | vangaindrano
# retreiving data | kaina
# retreiving data | craig
# retreiving data | aripuana
# retreiving data | dhidhdhoo
# retreiving data | marzuq
# retreiving data | ryotsu
# retreiving data | nchelenge
# retreiving data | nelson bay
# retreiving data | iracoubo
# retreiving data | the valley
# retreiving data | ola
# retreiving data | vanimo
# retreiving data | ossora
# retreiving data | nouadhibou
# retreiving data | port-gentil
# retreiving data | hameenlinna
# retreiving data | betare oya
# retreiving data | madimba
# retreiving data | ziro
# retreiving data | anloga
# If city is not found, skipping
# retreiving data | tevaitoa
# retreiving data | port-cartier
# retreiving data | nantucket
# retreiving data | fomboni
# retreiving data | straumen
# retreiving data | arequipa
# retreiving data | mangochi
# retreiving data | sao miguel do iguacu
# retreiving data | kashary
# retreiving data | ipameri
# retreiving data | sao geraldo do araguaia
# retreiving data | beira
# retreiving data | ixtapa
# retreiving data | kamaishi
# retreiving data | yomou
# retreiving data | ermoupolis
# retreiving data | axim
# retreiving data | rocha
# retreiving data | makakilo city
# retreiving data | concarneau
# retreiving data | burnie
# retreiving data | paris
# retreiving data | aguascalientes
# retreiving data | mahanoro
# retreiving data | emba
# retreiving data | norman wells
# retreiving data | rundu
# If city is not found, skipping
# retreiving data | listowel
# retreiving data | purpe
# retreiving data | tessalit
# retreiving data | derbent
# retreiving data | nuevo progreso
# retreiving data | nome
# retreiving data | aswan
# retreiving data | gien
# retreiving data | narsaq
# retreiving data | borba
# retreiving data | santa ana
# retreiving data | kinshasa
# retreiving data | dwarka
# retreiving data | porto novo
# retreiving data | tra vinh
# retreiving data | bilibino
# retreiving data | kosa
# retreiving data | wamba
# retreiving data | inhambane
# retreiving data | peleduy
# retreiving data | matagami
# retreiving data | clinton
# retreiving data | sechura
# retreiving data | denpasar
# retreiving data | tiarei
# retreiving data | luanda
# retreiving data | yanam
# If city is not found, skipping
# retreiving data | burhanpur
# retreiving data | coari
# retreiving data | pasighat
# retreiving data | zwettl
# retreiving data | placido de castro
# retreiving data | sao felix do xingu
# retreiving data | saint-augustin
# retreiving data | paamiut
# retreiving data | colac
# retreiving data | djambala
# retreiving data | dzaoudzi
# retreiving data | lorengau
# retreiving data | port macquarie
# retreiving data | terrace
# retreiving data | nabire
# If city is not found, skipping
# retreiving data | ust-ilimsk
# retreiving data | nago
# retreiving data | acapulco
# Retrieval is complete!
#              city country  latitude  longitude  max temp  humidity  \
# 0  port elizabeth      US     39.31     -74.98     17.22        47
# 1    saint george      GR     39.45      22.34     24.00        46
# 2     kotelnikovo      RU     47.63      43.14     20.56        65
# 3       busselton      AU    -33.64     115.35      8.89        65
# 4        pochutla      MX     15.74     -96.47     30.56        70
#
#    cloudiness  windspeed
# 0          20       5.10
# 1          20       3.10
# 2         100       8.03
# 3          63       5.88
# 4          40       1.18

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df.count()
# Out:
# city          549
# country       549
# latitude      549
# longitude     549
# max temp      549
# humidity      549
# cloudiness    549
# windspeed     549
# dtype: int64

# %%
#Convert file to csv and save
df.to_csv("weather_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
